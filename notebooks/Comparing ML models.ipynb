# %%
from matplotlib import pyplot as plt
import numpy as np
from numpy import random
random.seed(45)

# %%
X = random.rand(100)
Y_1 = X + 0.05*random.randn(len(X))
Y_2 = 1.0 - X + 0.2*random.randn(len(X))
plt.scatter(X, Y_1, c='b')
plt.scatter(X, Y_2, c='r')
plt.show()
