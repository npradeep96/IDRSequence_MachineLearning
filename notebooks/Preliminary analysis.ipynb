# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# read in data 
df = pd.read_csv('consolidated_data_matrix.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5777 entries, 0 to 5776
# Columns: 227 entries, f-hydrophobic to label
# dtypes: float64(124), int64(103)
# memory usage: 10.0 MB

# %%
df.describe()
# Out:
#        f-hydrophobic  f-neg_charge  f-pos_charge  f-sidechain_pipi  \
# count    5777.000000   5777.000000   5777.000000       5777.000000
# mean        0.325959      0.143498      0.126114          0.341931
# std         0.083651      0.093096      0.079619          0.107925
# min         0.042553      0.000000      0.000000          0.018692
# 25%         0.270833      0.076087      0.066667          0.269231
# 50%         0.319444      0.130081      0.113208          0.335443
# 75%         0.372093      0.191176      0.171717          0.406780
# max         0.772727      0.781818      0.524590          0.857143
#
#        hydrophobic-P_small  hydrophobic-P_medium  hydrophobic-P_large  \
# count          5777.000000           5777.000000          5777.000000
# mean              0.304223              0.202321             0.493456
# std               0.264549              0.219772             0.272999
# min               0.000000              0.000000             0.013889
# ...

# %%
print(df.corr())
# Out:
#                            f-hydrophobic  f-neg_charge  f-pos_charge  \
# f-hydrophobic                   1.000000     -0.345405     -0.414419
# f-neg_charge                   -0.345405      1.000000      0.074052
# f-pos_charge                   -0.414419      0.074052      1.000000
# f-sidechain_pipi               -0.502231      0.681727      0.287789
# hydrophobic-P_small            -0.154439      0.063191      0.071599
# hydrophobic-P_medium           -0.279457      0.115567      0.109623
# hydrophobic-P_large             0.374630     -0.154270     -0.157633
# hydrophobic-l_avg               0.560768     -0.247085     -0.242128
# hydrophobic-l_avg_norm          0.550081     -0.217953     -0.228859
# hydrophobic-l_max               0.401049     -0.185629     -0.183758
# hydrophobic-l_max_norm          0.583039     -0.227366     -0.259371
# neg_charge-P_small             -0.147345      0.324966      0.072338
# neg_charge-P_medium            -0.028890     -0.045239      0.057032
# ...

# %%
sns.heatmap(df.corr(), annot = True, fmt= '.2f')
# Out:
# /home/npradeep96/miniconda3/envs/fipyenv/lib/python2.7/site-packages/matplotlib/font_manager.py:1333: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
